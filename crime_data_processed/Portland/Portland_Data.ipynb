# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
import json

# %%
file_path = 'crime_data_raw/Portland_City/portland_city_raw_data.csv'
data_csv = pd.read_csv(file_path)
data_csv
portland_crime_df = pd.DataFrame(data_csv.rename(columns = {'Occur Date':'Date', 'Offense Type': 'OffenseType'}))
#portland_crime_df['Date'] = portland_crime_df['Date'].astype('datetime64[ns]')
# Out:
# C:\Users\misir\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
portland_crime_df.head(5)
# Out:
#                          Address Case Number Crime Against     Measure Names  \
# 0  SE DIVISION ST / SE 125TH AVE     15-4334      Property  No Measure Value
# 1    600 BLOCK OF SE POWELL BLVD    15-24565      Property  No Measure Value
# 2     1800 BLOCK OF NE 162ND AVE    15-26637       Society  No Measure Value
# 3    2100 BLOCK OF SW RIVER PKWY    15-30061       Society  No Measure Value
# 4    200 BLOCK OF SE MORRISON ST    15-63208        Person  No Measure Value
#
#         Neighborhood       Date  Occur Time         Offense Category  \
# 0          Mill Park  1/16/2015         700      Motor Vehicle Theft
# 1  Hosford-Abernethy  3/29/2015        2137                Vandalism
# 2             Wilkes  6/21/2015        1617  Animal Cruelty Offenses
# 3           Downtown   5/9/2015        1136   Drug/Narcotic Offenses
# 4       Buckman West  5/18/2015        1151         Assault Offenses
#
#                 OffenseType  Offense Count
# 0       Motor Vehicle Theft              1
# ...

# %%
crime_type_group = portland_crime_df.groupby(['OffenseType','Date'])['Offense Count'].count()
crime_type_count = pd.DataFrame(crime_type_group).reset_index()
#crime_type_count.sort_values(by = 'Offense Count', ascending = False).drop(columns = []
crime_type_count
# Out:
#                   OffenseType        Date  Offense Count
# 0          Aggravated Assault    1/1/2015              1
# 1          Aggravated Assault    1/1/2016             10
# 2          Aggravated Assault    1/1/2017              8
# 3          Aggravated Assault    1/1/2018              6
# 4          Aggravated Assault   1/10/2016              3
# 5          Aggravated Assault   1/10/2017              2
# 6          Aggravated Assault   1/10/2018              7
# 7          Aggravated Assault   1/11/2016              2
# 8          Aggravated Assault   1/11/2017              3
# 9          Aggravated Assault   1/11/2018              1
# 10         Aggravated Assault   1/12/2016              4
# 11         Aggravated Assault   1/12/2017              2
# 12         Aggravated Assault   1/12/2018              4
# 13         Aggravated Assault   1/13/2016              3
# 14         Aggravated Assault   1/13/2017              1
# ...
